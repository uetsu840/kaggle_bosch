# %% [markdown]
# 時間がかかるので引っ越し後にやってない。<br>
# いけるはず…

# %%
import os
import pandas as pd
import numpy as np
import math
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib import cm
from parse import *
import seaborn as sns

# %%
CHUNKSIZE = 100000

TRAIN_PATH        = "../../data/train_StationPathInfo.csv"
TRAIN_PATH_EX     = "../../data/train_StationPathInfoEx.csv"
TEST_PATH         = "../../data/test_StationPathInfo.csv"
TEST_PATH_EX      = "../../data/test_StationPathInfoEx.csv"

SEED = 0
CHUNKSIZE = 50000
NROWS = 1200000

ID_COLUMN = 'Id'
TARGET_COLUMN = 'Response'

# %%
# 読み出す。

df_train_bin = pd.read_csv(TRAIN_PATH)
df_test_bin  = pd.read_csv(TEST_PATH)
df_pass = pd.concat([df_train_bin, df_test_bin])

# %% [markdown]
# 通過ステーションをヒートマップにしてみる。

# %%
# 時系列でソートしたヒートマップを出してみる。

TEST_START_TIME      = "../../data/test_StartEndTime.csv"
TRAIN_START_TIME     = "../../data/train_StartEndTime.csv"

df_start_train = pd.read_csv(TRAIN_START_TIME)
df_start_train = df_start_train.ix[:,['Id','StartTime','EndTime', 'Response']]
df_start_test = pd.read_csv(TEST_START_TIME)
df_start_test['Response'] = -1
# Out:
# C:\Users\Tomonobu\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys

# %%
df_start_train.head()
# Out:
#    Id  StartTime  EndTime  Response
# 0   4      82.24    87.29         0
# 1   6    1313.12  1315.75         0
# 2   7    1618.70  1624.42         0
# 3   9    1149.20  1154.16         0
# 4  11     602.64   606.02         0

# %%
df_start_test.head()
df_start = pd.concat([df_start_train, df_start_test])
df_start.head()
# Out:
#    Id  StartTime  EndTime  Response
# 0   4      82.24    87.29         0
# 1   6    1313.12  1315.75         0
# 2   7    1618.70  1624.42         0
# 3   9    1149.20  1154.16         0
# 4  11     602.64   606.02         0

# %%
df_train = pd.merge(df_start, df_pass, how='left')
df_train = df_train.fillna(-1500)

# %%
df_train[df_train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Id, StartTime, EndTime, Response, L0_S0_D1, L0_S1_D26, L0_S2_D34, L0_S3_D70, L0_S4_D106, L0_S5_D115, L0_S6_D120, L0_S7_D137, L0_S8_D145, L0_S9_D152, L0_S10_D216, L0_S11_D280, L0_S12_D331, L0_S13_D355, L0_S14_D360, L0_S15_D395, L0_S16_D423, L0_S17_D432, L0_S18_D437, L0_S19_D454, L0_S20_D462, L0_S21_D469, L0_S22_D543, L0_S23_D617, L1_S24_D677, L1_S25_D1854, L2_S26_D3037, L2_S27_D3130, L2_S28_D3223, L3_S29_D3316, L3_S30_D3496, L3_S31_D3836, L3_S32_D3852, L3_S33_D3856, L3_S34_D3875, L3_S35_D3886, L3_S36_D3919, L3_S37_D3942, L3_S38_D3953, L3_S39_D3966, L3_S40_D3981, L3_S41_D3997, L3_S42_D4029, L3_S43_D4062, L3_S44_D4101, L3_S45_D4125, L3_S46_D4135, L3_S47_D4140, L3_S48_D4194, L3_S49_D4208, L3_S50_D4242, L3_S51_D4255]
# Index: []
#
# [0 rows x 56 columns]

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, log_loss, make_scorer

def calc_mcc(cf_mat):
    tn, fp, fn, tp = cf_mat.ravel()
    print(tn, fp, fn, tp)
    mcc = (tp * tn - fp * fn) / np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
    return mcc

def mcc_scorer(y_true, y_pred):
    cf_mat = confusion_matrix(y_true, y_pred)
    return calc_mcc(cf_mat)

def separate_X_y(df):
    X = df.drop(['Response'], axis=1)
    y = df['Response']
    return X, y

def train_with_r_forest(df):
    X_train, y_train = separate_X_y(df)

    cl_weight = {0:0.3, 1:0.7}
    
    # Grid Search
    params={'max_depth': [10, 25, 50],
            'subsample': [0.8, 0.9, 0.95],
            'colsample_bytree': [1.0],
            'scale_pos_weight': [2, 3, 4, 5]
    }

    xgb_model = xgb.XGBClassifier()
    gs = GridSearchCV(xgb_model,
                      params,
                      cv=5,
                      scoring={'mcc' : make_scorer(mcc_scorer)},
                      n_jobs=1,
                      verbose=2,
                      refit='mcc')

    gs.fit(X_train, y_train)
#rf = RandomForestClassifier(max_depth=10,n_estimators=50, random_state=33)
#    rf.fit(X_train, y_train)
    return gs

# %%
def train_rf_parameter(df):
    df = df[(df['Response'] == 0) | (df['Response'] == 1)]
    df_train, df_test = train_test_split(df, random_state=33)
    
    df_train_ok   = df_train[df_train['Response'] == 0]
    df_train_ng   = df_train[df_train['Response'] == 1]
    undersample_rate = len(df_train_ng) * 30 / len(df_train_ok)
    df_train_ok_sample = df_train_ok.sample(frac = undersample_rate)
    df_train = pd.concat([df_train_ok_sample, df_train_ng])

    rf = train_with_r_forest(df_train)
    X_test, y_test = separate_X_y(df_test)
    y_pred = rf.predict(X_test)
    print(y_pred)   
    
    cf_mat = confusion_matrix(y_test, y_pred)
    print(cf_mat)

    mcc = calc_mcc(cf_mat)
    print(mcc)    
    return rf

model = train_rf_parameter(df_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 31123 59 884 156
# 124590 138 3305 852
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  22.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   23.1s remaining:    0.0s
# 31094 88 891 149
# 124612 116 3265 892
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  22.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 31117 65 900 139
# 124594 134 3233 925
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  22.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 31089 93 875 164
# 124600 128 3243 915
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  22.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 31104 78 878 161
# 124604 124 3245 913
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  22.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 31124 58 879 161
# 124603 125 3284 873
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 31095 87 888 152
# 124625 103 3259 898
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  21.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 31117 65 903 136
# 124596 132 3221 937
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  21.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 31083 99 876 163
# 124602 126 3268 890
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  21.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 31104 78 877 162
# 124604 124 3256 902
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 31124 58 883 157
# 124595 133 3291 866
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  20.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 31089 93 885 155
# 124607 121 3262 895
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  20.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 31117 65 899 140
# 124596 132 3238 920
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  20.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 31091 91 880 159
# 124606 122 3259 899
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  21.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 31096 86 868 171
# 124608 120 3213 945
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  23.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 31096 86 867 173
# 124532 196 3136 1021
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  25.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 31080 102 874 166
# 124546 182 3128 1029
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  25.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 31100 82 892 147
# 124537 191 3072 1086
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  25.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 31072 110 869 170
# 124534 194 3137 1021
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  25.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 31084 98 863 176
# 124525 203 3084 1074
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  25.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 31098 84 874 166
# 124527 201 3149 1008
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  24.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 31080 102 878 162
# 124570 158 3115 1042
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  24.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 31100 82 879 160
# 124540 188 3054 1104
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  24.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 31061 121 873 166
# 124547 181 3128 1030
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  24.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 31079 103 859 180
# 124534 194 3092 1066
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  24.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 31098 84 865 175
# 124523 205 3148 1009
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  21.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 31073 109 868 172
# 124559 169 3139 1018
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  21.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 31087 95 878 161
# 124518 210 3045 1113
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  21.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 31069 113 869 170
# 124552 176 3138 1020
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 31080 102 860 179
# 124538 190 3108 1050
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  20.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 31082 100 859 181
# 124472 256 3029 1128
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  22.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 31057 125 866 174
# 124515 213 2979 1178
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  22.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 31078 104 871 168
# 124481 247 2923 1235
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  22.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 31045 137 860 179
# 124502 226 2987 1171
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  22.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 31073 109 856 183
# 124485 243 2950 1208
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  22.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 31086 96 858 182
# 124479 249 2996 1161
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  21.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 31069 113 863 177
# 124519 209 3038 1119
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  21.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 31076 106 867 172
# 124471 257 2919 1239
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  21.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 31049 133 864 175
# 124490 238 2949 1209
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  21.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 31069 113 853 186
# 124481 247 3005 1153
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  21.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 31091 91 861 179
# 124459 269 3034 1123
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  20.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 31056 126 864 176
# 124496 232 3033 1124
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  20.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 31066 116 874 165
# 124457 271 2925 1233
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  21.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 31047 135 861 178
# 124504 224 3030 1128
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 31063 119 846 193
# 124484 244 2966 1192
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 31066 116 847 193
# 124413 315 2879 1278
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  22.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 31045 137 856 184
# 124486 242 2900 1257
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  22.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 31062 120 871 168
# 124428 300 2832 1326
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  23.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 31025 157 856 183
# 124440 288 2852 1306
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  22.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 31047 135 850 189
# 124422 306 2852 1306
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  22.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 31070 112 848 192
# 124407 321 2942 1215
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  21.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 31045 137 858 182
# 124475 253 2924 1233
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  21.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 31060 122 866 173
# 124424 304 2828 1330
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  21.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 31040 142 854 185
# 124470 258 2837 1321
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  21.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 31051 131 847 192
# 124442 286 2867 1291
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  21.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 31069 113 852 188
# 124411 317 2944 1213
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 31041 141 855 185
# 124470 258 2920 1237
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 31046 136 865 174
# 124418 310 2864 1294
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  20.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 31033 149 851 188
# 124451 277 2916 1242
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  20.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 31044 138 849 190
# 124419 309 2865 1293
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  20.7s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 31080 102 861 179
# 124717 11 544 3613
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  56.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 31062 120 861 179
# 124713 15 440 3717
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  55.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 31073 109 871 168
# 124713 15 462 3696
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  55.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 31058 124 854 185
# 124718 10 384 3774
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  55.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 31051 131 846 193
# 124721 7 527 3631
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  55.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 31086 96 858 182
# 124721 7 578 3579
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  54.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 31052 130 857 183
# 124720 8 616 3541
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  53.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 31069 113 873 166
# 124722 6 424 3734
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  54.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 31063 119 845 194
# 124724 4 515 3643
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  53.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 31046 136 850 189
# 124720 8 555 3603
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  54.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 31093 89 851 189
# 124719 9 617 3540
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  53.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 31061 121 853 187
# 124718 10 598 3559
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  53.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 31069 113 866 173
# 124720 8 566 3592
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  53.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 31057 125 849 190
# 124719 9 624 3534
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  52.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 31049 133 851 188
# 124719 9 619 3539
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  53.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 31058 124 842 198
# 124701 27 28 4129
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  57.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 31041 141 840 200
# 124703 25 62 4095
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  57.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 31043 139 865 174
# 124699 29 41 4117
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  57.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 31021 161 832 207
# 124704 24 39 4119
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  56.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 31025 157 828 211
# 124699 29 32 4126
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  57.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 31051 131 839 201
# 124705 23 96 4061
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  55.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 31025 157 835 205
# 124703 25 72 4085
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  55.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 31026 156 855 184
# 124709 19 59 4099
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  55.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 31020 162 835 204
# 124711 17 33 4125
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  54.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 31006 176 827 212
# 124704 24 59 4099
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  55.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 31053 129 833 207
# 124708 20 53 4104
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  53.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 31023 159 842 198
# 124709 19 79 4078
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  54.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 31038 144 850 189
# 124702 26 100 4058
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  54.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 31015 167 833 206
# 124702 26 52 4106
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  54.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 31000 182 824 215
# 124710 18 122 4036
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  53.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 31042 140 834 206
# 124687 41 0 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  57.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 31010 172 837 203
# 124686 42 1 4156
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  57.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 31013 169 848 191
# 124680 48 5 4153
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  57.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 30991 191 824 215
# 124682 46 2 4156
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  57.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 31005 177 830 209
# 124687 41 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  57.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 31026 156 833 207
# 124695 33 6 4151
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  55.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 30984 198 833 207
# 124690 38 3 4154
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  58.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 31006 176 854 185
# 124692 36 5 4153
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  55.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 30979 203 827 212
# 124686 42 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  55.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 30986 196 820 219
# 124685 43 1 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  55.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 31023 159 832 208
# 124690 38 3 4154
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  54.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 30980 202 834 206
# 124695 33 4 4153
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  54.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 31000 182 847 192
# 124692 36 5 4153
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  54.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 30977 205 830 209
# 124697 31 2 4156
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  54.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 30981 201 818 221
# 124696 32 16 4142
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  54.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 31014 168 825 215
# 124678 50 0 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  57.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 30981 201 828 212
# 124681 47 0 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  57.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 31001 181 850 189
# 124676 52 1 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  57.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 30964 218 820 219
# 124682 46 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  57.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 30968 214 820 219
# 124674 54 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  57.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 31007 175 829 211
# 124676 52 0 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  55.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 30966 216 825 215
# 124685 43 0 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  55.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 30994 188 842 197
# 124686 42 1 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  55.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 30971 211 821 218
# 124689 39 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  56.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 30965 217 822 217
# 124688 40 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  55.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 30979 203 830 210
# 124695 33 0 4157
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  54.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 30962 220 823 217
# 124692 36 1 4156
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  54.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 30974 208 837 202
# 124688 40 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  54.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 30950 232 816 223
# 124686 42 0 4158
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  54.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 30963 219 816 223
# 124690 38 4 4154
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  54.6s
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 31065 117 847 193
# 124721 7 5 4152
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 31047 135 855 185
# 124725 3 7 4150
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 31065 117 875 164
# 124725 3 5 4153
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 31041 141 845 194
# 124726 2 8 4150
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 31030 152 846 193
# 124724 4 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 31067 115 841 199
# 124722 6 3 4154
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 31041 141 849 191
# 124723 5 4 4153
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 31055 127 873 166
# 124724 4 1 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 31043 139 842 197
# 124726 2 6 4152
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 31026 156 841 198
# 124726 2 5 4153
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 31060 122 842 198
# 124723 5 1 4156
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 31046 136 842 198
# 124723 5 15 4142
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 31048 134 867 172
# 124725 3 1 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 31037 145 836 203
# 124724 4 1 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 31020 162 844 195
# 124725 3 4 4154
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 31053 129 840 200
# 124721 7 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 31024 158 844 196
# 124717 11 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 31034 148 868 171
# 124720 8 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 31011 171 837 202
# 124721 7 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 31004 178 833 206
# 124719 9 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 31043 139 835 205
# 124718 10 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 31012 170 837 203
# 124716 12 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 31014 168 853 186
# 124723 5 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 31004 178 836 203
# 124722 6 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 30991 191 825 214
# 124720 8 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 31039 143 834 206
# 124720 8 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 31012 170 837 203
# 124720 8 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 31010 172 856 183
# 124724 4 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 31001 181 830 209
# 124723 5 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 30978 204 825 214
# 124723 5 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 31029 153 839 201
# 124715 13 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 31002 180 837 203
# 124709 19 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 31008 174 851 188
# 124716 12 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 31001 181 826 213
# 124715 13 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 30992 190 826 213
# 124716 12 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 31011 171 836 204
# 124717 11 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 30987 195 833 207
# 124717 11 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 30992 190 846 193
# 124720 8 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 30975 207 829 210
# 124718 10 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 30977 205 815 224
# 124722 6 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 31014 168 830 210
# 124716 12 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 30962 220 830 210
# 124717 11 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 30990 192 846 193
# 124722 6 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 30964 218 823 216
# 124720 8 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 30954 228 818 221
# 124719 9 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 31016 166 828 212
# 124717 11 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 30987 195 828 212
# 124712 16 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 30999 183 856 183
# 124713 15 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 30976 206 830 209
# 124717 11 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 30985 197 824 215
# 124714 14 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 30999 183 827 213
# 124716 12 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 30965 217 834 206
# 124714 14 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 30983 199 844 195
# 124721 7 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 30966 216 829 210
# 124720 8 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 30946 236 822 217
# 124714 14 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 30987 195 826 214
# 124717 11 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 30947 235 827 213
# 124720 8 0 4157
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 30967 215 842 197
# 124722 6 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 30963 219 819 220
# 124720 8 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.6min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 30943 239 817 222
# 124714 14 0 4158
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.6min
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 177.4min finished
# [0 0 0 ..., 0 0 0]
# [[292995   1260]
#  [  1365    317]]
# 292995 1260 1365 317
# 0.190183064385

# %%
model.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1.0,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=25,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=2, seed=0, silent=True, subsample=0.95)

# %%
def train_and_predict_one_chnuk(df_train):
    df_train_ok   = df_train[df_train['Response'] == 0]
    df_train_ng   = df_train[df_train['Response'] == 1]
    df_test = df_train[df_train['Response'] == -1]
    
    undersample_rate = len(df_train_ng) * 20 / len(df_train_ok)
    df_train_ok_sample = df_train_ok.sample(frac = undersample_rate)

    df_train_balance = pd.concat([df_train_ok_sample, df_train_ng])
    
    rf = train_with_r_forest(df_train_balance)

    X_test, y_test = separate_X_y(df_test)
    y_pred = rf.predict(X_test)
      
    df_result_add = pd.DataFrame(columns=['Id', 'Response'])
    df_result_add.loc[:, 'Id']       = df_test['Id'].values
    df_result_add.loc[:, 'Response'] = y_pred
    
    return df_result_add

df_result = train_and_predict_one_chnuk(df_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 27412 104 1376 0
# 109866 198 4309 1194
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   21.2s remaining:    0.0s
# 27429 87 1376 0
# 109899 165 4129 1374
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  22.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 27418 98 1376 0
# 109896 168 4164 1339
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  21.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 27409 107 1376 0
# 109868 196 4111 1392
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  20.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8
# 27417 99 1375 0
# 109842 222 4264 1240
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.8, total=  21.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 27401 115 1376 0
# 109850 214 4238 1265
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  20.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 27417 99 1376 0
# 109900 164 4149 1354
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  19.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 27417 99 1376 0
# 109907 157 4125 1378
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 27407 109 1376 0
# 109870 194 4122 1381
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  19.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9
# 27414 102 1375 0
# 109831 233 4241 1263
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.9, total=  19.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 27402 114 1376 0
# 109858 206 4280 1223
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 27425 91 1376 0
# 109892 172 4140 1363
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  19.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 27417 99 1376 0
# 109890 174 4125 1378
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  18.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 27409 107 1376 0
# 109869 195 4116 1387
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  19.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95
# 27417 99 1375 0
# 109846 218 4238 1266
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=2, subsample=0.95, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 27385 131 1376 0
# 109763 301 4057 1446
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  20.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 27405 111 1376 0
# 109813 251 3871 1632
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 27386 130 1376 0
# 109813 251 3813 1690
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  20.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 27384 132 1376 0
# 109767 297 3857 1646
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  20.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8
# 27395 121 1375 0
# 109761 303 4029 1475
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.8, total=  20.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 27378 138 1376 0
# 109791 273 4087 1416
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  19.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 27402 114 1376 0
# 109816 248 3924 1579
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 27390 126 1371 5
# 109812 252 3894 1609
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  19.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 27393 123 1376 0
# 109778 286 3868 1635
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9
# 27385 131 1375 0
# 109748 316 4011 1493
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.9, total=  20.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 27380 136 1376 0
# 109797 267 4104 1399
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 27396 120 1376 0
# 109820 244 3876 1627
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  19.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 27396 120 1376 0
# 109827 237 3868 1635
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  19.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 27381 135 1376 0
# 109777 287 3858 1645
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  19.2s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95
# 27387 129 1375 0
# 109756 308 4054 1450
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=3, subsample=0.95, total=  19.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 27334 182 1376 0
# 109667 397 3835 1668
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  20.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 27367 149 1376 0
# 109710 354 3585 1918
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 27355 161 1376 0
# 109699 365 3553 1950
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  20.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 27343 173 1375 1
# 109673 391 3570 1933
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8
# 27348 168 1375 0
# 109622 442 3844 1660
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.8, total=  20.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 27342 174 1376 0
# 109689 375 3857 1646
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  19.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 27368 148 1374 2
# 109751 313 3590 1913
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 27359 157 1364 12
# 109732 332 3583 1920
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  19.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 27359 157 1376 0
# 109673 391 3614 1889
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9
# 27359 157 1375 0
# 109647 417 3828 1676
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.9, total=  20.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 27340 176 1376 0
# 109677 387 3871 1632
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  19.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 27375 141 1372 4
# 109759 305 3708 1795
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  19.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 27360 156 1344 32
# 109732 332 3606 1897
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  19.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 27338 178 1376 0
# 109662 402 3596 1907
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  19.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95
# 27356 160 1375 0
# 109644 420 3872 1632
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=4, subsample=0.95, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 27274 242 1376 0
# 109550 514 3603 1900
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 27318 198 1374 2
# 109582 482 3270 2233
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 27294 222 1375 1
# 109539 525 3193 2310
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  20.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 27271 245 1375 1
# 109525 539 3222 2281
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  20.8s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8
# 27311 205 1375 0
# 109544 520 3560 1944
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.8, total=  20.6s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 27295 221 1376 0
# 109576 488 3594 1909
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  19.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 27313 203 1374 2
# 109612 452 3376 2127
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  19.7s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 27298 218 1362 14
# 109573 491 3298 2205
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  19.3s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 27286 230 1373 3
# 109560 504 3337 2166
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  19.5s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9
# 27312 204 1375 0
# 109500 564 3603 1901
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.9, total=  19.9s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 27299 217 1376 0
# 109615 449 3653 1850
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  19.4s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 27303 213 1374 2
# 109592 472 3361 2142
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  19.1s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 27316 200 1359 17
# 109607 457 3350 2153
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  19.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 27290 226 1375 1
# 109543 521 3360 2143
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  19.0s
# [CV] colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95
# 27319 197 1375 0
# 109559 505 3648 1856
# [CV]  colsample_bytree=1.0, max_depth=10, scale_pos_weight=5, subsample=0.95, total=  19.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 27324 192 1376 0
# 110025 39 426 5077
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  52.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 27332 184 1376 0
# 110037 27 292 5211
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  51.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 27342 174 1376 0
# 110035 29 233 5270
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  51.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 27332 184 1376 0
# 110033 31 330 5173
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  51.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8
# 27305 211 1375 0
# 110023 41 471 5033
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.8, total=  52.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 27321 195 1376 0
# 110026 38 499 5004
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  51.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 27326 190 1376 0
# 110045 19 233 5270
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  50.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 27337 179 1376 0
# 110043 21 202 5301
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  49.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 27316 200 1376 0
# 110035 29 241 5262
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  50.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9
# 27318 198 1375 0
# 110031 33 598 4906
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.9, total=  50.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 27326 190 1376 0
# 110038 26 477 5026
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  50.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 27335 181 1376 0
# 110041 23 270 5233
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  49.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 27339 177 1376 0
# 110049 15 203 5300
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  49.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 27313 203 1376 0
# 110041 23 268 5235
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  49.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95
# 27305 211 1375 0
# 110034 30 569 4935
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=2, subsample=0.95, total=  50.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 27261 255 1376 0
# 109996 68 27 5476
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  52.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 27274 242 1376 0
# 110009 55 19 5484
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  51.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 27291 225 1375 1
# 110014 50 14 5489
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  51.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 27281 235 1375 1
# 109997 67 14 5489
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  51.7s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8
# 27255 261 1375 0
# 109984 80 34 5470
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.8, total=  52.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 27256 260 1376 0
# 110007 57 64 5439
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  51.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 27265 251 1376 0
# 110022 42 22 5481
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  51.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 27280 236 1369 7
# 110014 50 6 5497
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  50.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 27255 261 1376 0
# 110014 50 23 5480
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  50.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9
# 27248 268 1375 0
# 110011 53 69 5435
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.9, total=  51.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 27240 276 1376 0
# 109997 67 66 5437
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  50.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 27268 248 1376 0
# 110022 42 34 5469
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  50.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 27285 231 1376 0
# 110032 32 13 5490
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  49.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 27263 253 1376 0
# 110013 51 14 5489
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  50.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95
# 27225 291 1375 0
# 110008 56 92 5412
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=3, subsample=0.95, total=  50.7s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 27210 306 1376 0
# 109951 113 5 5498
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  52.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 27239 277 1374 2
# 109980 84 2 5501
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  52.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 27255 261 1376 0
# 109980 84 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  51.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 27232 284 1375 1
# 109975 89 2 5501
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  52.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8
# 27199 317 1375 0
# 109962 102 3 5501
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.8, total=  52.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 27196 320 1376 0
# 109962 102 2 5501
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  51.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 27217 299 1376 0
# 109989 75 4 5499
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  50.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 27233 283 1370 6
# 109998 66 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  50.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 27237 279 1373 3
# 109989 75 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  50.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9
# 27185 331 1375 0
# 109975 89 8 5496
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.9, total=  51.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 27181 335 1376 0
# 109973 91 1 5502
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  50.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 27207 309 1374 2
# 110004 60 3 5500
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  50.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 27230 286 1374 2
# 109999 65 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  50.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 27219 297 1375 1
# 109997 67 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  49.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95
# 27164 352 1375 0
# 109984 80 9 5495
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=4, subsample=0.95, total=  50.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 27193 323 1376 0
# 109945 119 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  53.1s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 27202 314 1374 2
# 109952 112 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  51.9s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 27218 298 1372 4
# 109958 106 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  51.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 27205 311 1372 4
# 109957 107 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  51.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8
# 27175 341 1375 0
# 109943 121 0 5504
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.8, total=  52.7s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 27159 357 1376 0
# 109950 114 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  51.5s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 27155 361 1374 2
# 109975 89 1 5502
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  50.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 27203 313 1370 6
# 109983 81 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  50.6s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 27180 336 1371 5
# 109974 90 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  50.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9
# 27133 383 1375 0
# 109957 107 0 5504
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.9, total=  51.4s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 27135 381 1376 0
# 109956 108 3 5500
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  51.2s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 27152 364 1376 0
# 109995 69 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  50.3s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 27197 319 1366 10
# 109977 87 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  49.8s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 27164 352 1373 3
# 109979 85 0 5503
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  50.0s
# [CV] colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95
# 27113 403 1375 0
# 109968 96 0 5504
# [CV]  colsample_bytree=1.0, max_depth=25, scale_pos_weight=5, subsample=0.95, total=  50.6s
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 27314 202 1376 0
# 110053 11 1 5502
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 27318 198 1376 0
# 110050 14 1 5502
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 27327 189 1376 0
# 110054 10 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 27314 202 1376 0
# 110052 12 1 5502
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8
# 27285 231 1375 0
# 110055 9 1 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 27296 220 1376 0
# 110055 9 3 5500
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 27306 210 1376 0
# 110060 4 1 5502
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 27328 188 1375 1
# 110057 7 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 27303 213 1376 0
# 110052 12 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9
# 27280 236 1375 0
# 110059 5 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 27289 227 1376 0
# 110056 8 1 5502
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 27301 215 1376 0
# 110061 3 3 5500
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 27328 188 1375 1
# 110058 6 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 27281 235 1375 1
# 110052 12 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95
# 27264 252 1375 0
# 110057 7 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=2, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 27253 263 1376 0
# 110044 20 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 27259 257 1374 2
# 110045 19 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 27286 230 1375 1
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 27290 226 1375 1
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8
# 27254 262 1375 0
# 110047 17 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 27241 275 1376 0
# 110049 15 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 27241 275 1374 2
# 110053 11 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 27271 245 1376 0
# 110053 11 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 27268 248 1375 1
# 110048 16 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9
# 27239 277 1375 0
# 110050 14 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 27214 302 1376 0
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 27233 283 1374 2
# 110053 11 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 27269 247 1375 1
# 110052 12 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 27247 269 1373 3
# 110051 13 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95
# 27207 309 1375 0
# 110053 11 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=3, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 27224 292 1376 0
# 110029 35 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 27213 303 1376 0
# 110036 28 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 27268 248 1375 1
# 110039 25 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 27251 265 1376 0
# 110034 30 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8
# 27218 298 1375 0
# 110038 26 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 27201 315 1376 0
# 110040 24 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 27225 291 1372 4
# 110052 12 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 27237 279 1375 1
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 27233 283 1372 4
# 110040 24 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9
# 27195 321 1375 0
# 110040 24 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 27177 339 1376 0
# 110038 26 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 27197 319 1371 5
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 27227 289 1369 7
# 110048 16 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 27203 313 1372 4
# 110043 21 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95
# 27151 365 1375 0
# 110041 23 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=4, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 27190 326 1376 0
# 110034 30 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 27210 306 1376 0
# 110041 23 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 27231 285 1372 4
# 110039 25 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 27216 300 1375 1
# 110032 32 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8
# 27191 325 1375 0
# 110033 31 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.8, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 27168 348 1376 0
# 110038 26 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 27176 340 1373 3
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 27206 310 1369 7
# 110044 20 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 27190 326 1371 5
# 110036 28 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9
# 27145 371 1375 0
# 110035 29 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.9, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 27134 382 1376 0
# 110026 38 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.5min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 27155 361 1370 6
# 110046 18 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 27207 309 1369 7
# 110048 16 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 27169 347 1370 6
# 110043 21 0 5503
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.4min
# [CV] colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95
# 27141 375 1375 0
# 110040 24 0 5504
# [CV]  colsample_bytree=1.0, max_depth=50, scale_pos_weight=5, subsample=0.95, total= 1.5min
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 162.2min finished

# %%
df_result[df_result['Response']==1].shape
# Out:
# (8157, 2)

# %%
df_result[df_result['Response']==0].shape
# Out:
# (1175591, 2)

# %%
df_result.to_csv("../../submission/submit_20180621_2.csv", index=False)

# %% [markdown]
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1.0,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=25,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=2, seed=0, silent=True, subsample=0.95)
