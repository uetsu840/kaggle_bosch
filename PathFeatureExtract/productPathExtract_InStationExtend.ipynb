# %%
import os
import pandas as pd
import numpy as np
import math
from matplotlib.pyplot import *
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib import cm
from parse import *
import seaborn as sns

# %%
CHUNKSIZE = 100000

TRAIN_DATE        = "./train_date.csv"
TRAIN_NUMERIC     = "./train_numeric.csv"
TRAIN_CATEGORICAL = "./train_categorical.csv"
TEST_DATE         = "./test_date.csv"
TEST_NUMERIC      = "./test_numeric.csv"
TEST_CATEGORICAL  = "./test_categorical.csv"

SEED = 0
CHUNKSIZE = 50000
NROWS = 1200000

ID_COLUMN = 'Id'
TARGET_COLUMN = 'Response'

# %%
chunk_train_date = pd.read_csv(TRAIN_DATE, nrows=NROWS, chunksize=CHUNKSIZE)
chunk_test_date  = pd.read_csv(TEST_DATE, nrows=NROWS, chunksize=CHUNKSIZE)
chunk_train_numeric = pd.read_csv(TRAIN_NUMERIC, nrows=NROWS, chunksize=CHUNKSIZE)
chunk_test_numeric  = pd.read_csv(TEST_NUMERIC, nrows=NROWS, chunksize=CHUNKSIZE)
chunk_train_categorical = pd.read_csv(TRAIN_CATEGORICAL, nrows=NROWS, chunksize=CHUNKSIZE)
chunk_test_categorical  = pd.read_csv(TEST_CATEGORICAL, nrows=NROWS, chunksize=CHUNKSIZE)

df_train_date = chunk_train_date.get_chunk(10)
df_test_date  = chunk_test_date.get_chunk(10)
df_train_numeric = chunk_train_numeric.get_chunk(10)
df_test_numeric  = chunk_test_numeric.get_chunk(10)
df_train_categorical = chunk_train_categorical.get_chunk(10)
df_test_categorical  = chunk_test_categorical.get_chunk(10)

# %%
df_train_date.head()
# Out:
#    Id  L0_S0_D1  L0_S0_D3  L0_S0_D5  L0_S0_D7  L0_S0_D9  L0_S0_D11  L0_S0_D13  \
# 0   4     82.24     82.24     82.24     82.24     82.24      82.24      82.24
# 1   6       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2   7   1618.70   1618.70   1618.70   1618.70   1618.70    1618.70    1618.70
# 3   9   1149.20   1149.20   1149.20   1149.20   1149.20    1149.20    1149.20
# 4  11    602.64    602.64    602.64    602.64    602.64     602.64     602.64
#
#    L0_S0_D15  L0_S0_D17      ...       L3_S50_D4246  L3_S50_D4248  \
# 0      82.24      82.24      ...                NaN           NaN
# 1        NaN        NaN      ...                NaN           NaN
# 2    1618.70    1618.70      ...                NaN           NaN
# 3    1149.20    1149.20      ...                NaN           NaN
# 4     602.64     602.64      ...                NaN           NaN
#
#    L3_S50_D4250  L3_S50_D4252  L3_S50_D4254  L3_S51_D4255  L3_S51_D4257  \
# ...

# %%
df_train_numeric.head()
# Out:
#    Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  L0_S0_F12  \
# 0   4     0.030    -0.034    -0.197    -0.179     0.118      0.116     -0.015
# 1   6       NaN       NaN       NaN       NaN       NaN        NaN        NaN
# 2   7     0.088     0.086     0.003    -0.052     0.161      0.025     -0.015
# 3   9    -0.036    -0.064     0.294     0.330     0.074      0.161      0.022
# 4  11    -0.055    -0.086     0.294     0.330     0.118      0.025      0.030
#
#    L0_S0_F14  L0_S0_F16    ...     L3_S50_F4245  L3_S50_F4247  L3_S50_F4249  \
# 0     -0.032      0.020    ...              NaN           NaN           NaN
# 1        NaN        NaN    ...              NaN           NaN           NaN
# 2     -0.072     -0.225    ...              NaN           NaN           NaN
# 3      0.128     -0.026    ...              NaN           NaN           NaN
# 4      0.168     -0.169    ...              NaN           NaN           NaN
#
# ...

# %%
df_train_categorical.head()
# Out:
#    Id  L0_S1_F25  L0_S1_F27  L0_S1_F29  L0_S1_F31  L0_S2_F33  L0_S2_F35  \
# 0   4        NaN        NaN        NaN        NaN        NaN        NaN
# 1   6        NaN        NaN        NaN        NaN        NaN        NaN
# 2   7        NaN        NaN        NaN        NaN        NaN        NaN
# 3   9        NaN        NaN        NaN        NaN        NaN        NaN
# 4  11        NaN        NaN        NaN        NaN        NaN        NaN
#
#    L0_S2_F37  L0_S2_F39  L0_S2_F41      ...       L3_S49_F4225  L3_S49_F4227  \
# 0        NaN        NaN        NaN      ...                NaN           NaN
# 1        NaN        NaN        NaN      ...                NaN           NaN
# 2        NaN        NaN        NaN      ...                NaN           NaN
# 3        NaN        NaN        NaN      ...                NaN           NaN
# 4        NaN        NaN        NaN      ...                NaN           NaN
#
# ...

# %% [markdown]
# categorical の D, numeric の S, categorical の F が重複しない通し番号になっているようだ。
